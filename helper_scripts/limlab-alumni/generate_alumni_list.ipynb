# %%
initial_list = [
    {
      "Name": "Cece Zhang",
      "Position": "Junior Specialist",
      "Years": "2021-2024",
      "Subsequently": "Ph.D. Student, USC Bioengineering",
      "Lab Website": ""
    },
    {
      "Name": "An Tran",
      "Position": "Junior Specialist",
      "Years": "2021-2024",
      "Subsequently": "Ph.D. Student, USC Bioengineering",
      "Lab Website": ""
    },
    {
      "Name": "Harkiran Bhasin",
      "Position": "Junior Specialist",
      "Years": "2021-2024",
      "Subsequently": "M.D. Student, California Health Science University",
      "Lab Website": ""
    },
    {
      "Name": "Ben Ng",
      "Position": "Visiting Student, Junior Specialist",
      "Years": "2021-2024",
      "Subsequently": "Ph.D. Student, University of California, Santa Barbara",
      "Lab Website": ""
    },
    {
      "Name": "Nishith Reddy, PhD",
      "Position": "Graduate Student",
      "Years": "2016-2024",
      "Subsequently": "Postdoctoral Fellow, MIT (Lab of Feng Zhang)",
      "Lab Website": ""
    },
    {
      "Name": "Greg Allen, MD, PhD",
      "Position": "Postdoc",
      "Years": "2015-2023",
      "Subsequently": "Assistant Professor, UCSF",
      "Lab Website": "https://allen-lab.org/"
    },
    {
      "Name": "Ki Kim, PhD",
      "Position": "Graduate Student",
      "Years": "2017-2023",
      "Subsequently": "",
      "Lab Website": ""
    },
    {
      "Name": "Jeremy Villafuerte",
      "Position": "Specialist",
      "Years": "2020-2023",
      "Subsequently": "",
      "Lab Website": ""
    },
    {
      "Name": "Kyle Daniels, PhD",
      "Position": "Postdoc",
      "Years": "2015-2022",
      "Subsequently": "Assistant Professor, Stanford University",
      "Lab Website": "https://danielssynbio.net/"
    },
    {
      "Name": "Rogelio Hernandez-Lopez, PhD",
      "Position": "Postdoc",
      "Years": "2016-2021",
      "Subsequently": "Assistant Professor, Stanford University",
      "Lab Website": "https://www.hl-lab.org/"
    },
    {
      "Name": "Jason Duecker",
      "Position": "Staff Research Associate",
      "Years": "2019-2022",
      "Subsequently": "Lyell Immunopharma",
      "Lab Website": ""
    },
    {
      "Name": "Michael Broeker",
      "Position": "Lab Manager",
      "Years": "2013-2021",
      "Subsequently": "Lab Operations Manager, Septerna",
      "Lab Website": ""
    },
    {
      "Name": "Wesley Mckeithan, PhD",
      "Position": "Postdoc",
      "Years": "2018-2020",
      "Subsequently": "Scientist II, Maze Therapeutics",
      "Lab Website": ""
    },
    {
      "Name": "Aileen Li, PhD",
      "Position": "Postdoc",
      "Years": "2018-2020",
      "Subsequently": "Principal Scientist, Lyell Immunopharma",
      "Lab Website": ""
    },
    {
      "Name": "Joseph Choe, PhD",
      "Position": "Graduate Student",
      "Years": "2014-2020",
      "Subsequently": "Scientist II, Arsenal Bio",
      "Lab Website": ""
    },
    {
      "Name": "Maia Yoshida",
      "Position": "Research Assistant",
      "Years": "2018-2020",
      "Subsequently": "Master’s Degree in STEM Education Student, King's College London",
      "Lab Website": ""
    },
    {
      "Name": "Geoffrey O'Donoghue, PhD",
      "Position": "Postdoc",
      "Years": "2014-2020",
      "Subsequently": "Scientist, Cero Therapeutics",
      "Lab Website": ""
    },
    {
      "Name": "Jasper Williams, PhD",
      "Position": "Graduate Student",
      "Years": "2014-2020",
      "Subsequently": "Scientist, ArsenalBio",
      "Lab Website": ""
    },
    {
      "Name": "Nicholas Frankel, PhD",
      "Position": "Postdoc",
      "Years": "2015-2019",
      "Subsequently": "Scientist II, Senti Biosciences",
      "Lab Website": ""
    },
    {
      "Name": "Satoshi Toda, PhD",
      "Position": "Postdoc",
      "Years": "2015-2019",
      "Subsequently": "Assistant Professor, Nano Life Science Institute, Kanazawa University, Japan",
      "Lab Website": "https://sites.google.com/view/satoshitodalab/home"
    },
    {
      "Name": "Ashley Koegel, MD",
      "Position": "Postdoc",
      "Years": "2017-2019",
      "Subsequently": "Medical Director, Celgene",
      "Lab Website": ""
    },
    {
      "Name": "Vivian Garcia",
      "Position": "Visiting Scholar",
      "Years": "2018-2019",
      "Subsequently": "Biological and Biomedical Sciences PhD Student, Harvard University",
      "Lab Website": ""
    },
    {
      "Name": "Nira Krasnow",
      "Position": "Research Technician",
      "Years": "2018-2019",
      "Subsequently": "Medical Student, Harvard Medical School",
      "Lab Website": ""
    },
    {
      "Name": "Jonathan Brunger, PhD",
      "Position": "Postdoc",
      "Years": "2015-2019",
      "Subsequently": "Assistant Professor, Vanderbilt University, School of Engineering",
      "Lab Website": "https://brungerlab.com/"
    },
    {
      "Name": "Joan Garbarino",
      "Position": "Lab Manager",
      "Years": "2009-2019",
      "Subsequently": "Retired",
      "Lab Website": ""
    },
    {
      "Name": "Sarah Levinson",
      "Position": "Postdoc",
      "Years": "2016-2019",
      "Subsequently": "Scientist, Kyverna Therapeutics",
      "Lab Website": ""
    },
    {
      "Name": "Igal Sterin",
      "Position": "Research Technician",
      "Years": "2015-2018",
      "Subsequently": "Molecular Biology Ph.D. Student, University of Utah",
      "Lab Website": ""
    },
    {
      "Name": "Crystal Ghosh",
      "Position": "Research Technician",
      "Years": "2016-2018",
      "Subsequently": "Research Associate, Calico Life Sciences",
      "Lab Website": ""
    },
    {
      "Name": "Jakub Rajniak",
      "Position": "Postdoctoral Fellow",
      "Years": "2016-2017",
      "Subsequently": "Postdoctoral Fellow, Stanford University",
      "Lab Website": ""
    },
    {
      "Name": "Lukasz Bugaj",
      "Position": "Postdoc",
      "Years": "2014-2017",
      "Subsequently": "Assistant Professor, University of Pennsylvania, Dept. of Bioengineering",
      "Lab Website": "https://www.bugajlab.com/"
    },
    {
      "Name": "Kole Roybal",
      "Position": "Postdoc",
      "Years": "2013-2017",
      "Subsequently": "Assistant Professor, University of California, San Francisco, Dept. of Microbiology and Immunology",
      "Lab Website": "https://www.roybal-lab.org/"
    },
    {
      "Name": "Isabel Kolinko",
      "Position": "Postdoc",
      "Years": "2015-2017",
      "Subsequently": "Professur, Institute for Microbiology, ETH Zurich",
      "Lab Website": ""
    },
    {
      "Name": "Russell Gordley",
      "Position": "Postdoc",
      "Years": "2009-2016",
      "Subsequently": "Synthetic Biology Group Leader, Senti Biosciences",
      "Lab Website": ""
    },
    {
      "Name": "Leonardo Morsut",
      "Position": "Postdoc",
      "Years": "2012-2016",
      "Subsequently": "Assistant Professor, Dept. of Stem Cell Biology and Regenerative Medicine, University of Southern California",
      "Lab Website": "http://morsutlab.usc.edu/"
    },
    {
      "Name": "Amir Mitchell",
      "Position": "Postdoc",
      "Years": "2012-2016",
      "Subsequently": "Assistant Professor, University of Massachusetts Medical School",
      "Lab Website": "https://mitchell-lab.umassmed.edu/"
    },
    {
      "Name": "Scott Coyle",
      "Position": "Graduate Student",
      "Years": "2009-2016",
      "Subsequently": "Assistant Professor, UW-Madison",
      "Lab Website": "https://www.coylelab.org/"
    },
    {
      "Name": "Levi Rupp",
      "Position": "Postdoc",
      "Years": "2014-2016",
      "Subsequently": "Associate Director, Janssen Pharmaceutica",
      "Lab Website": ""
    },
    {
      "Name": "Krista McNally",
      "Position": "Specialist",
      "Years": "2010-2016",
      "Subsequently": "Scientist, Chimera Bioengineering",
      "Lab Website": ""
    },
    {
      "Name": "Xin Xiong",
      "Position": "Postdoc",
      "Years": "2013-2015",
      "Subsequently": "Lead Scientist, Agenovir Corporation",
      "Lab Website": ""
    },
    {
      "Name": "Kara Helmke",
      "Position": "Education Coordinator",
      "Years": "2013-2015",
      "Subsequently": "Lecturer in Bioengineering, Stanford University",
      "Lab Website": ""
    },
    {
      "Name": "Chia-Yung Wu",
      "Position": "Postdoc",
      "Years": "2010-2015",
      "Subsequently": "Scientist, Amgen",
      "Lab Website": ""
    },
    {
      "Name": "Whitney Walker",
      "Position": "Junior Specialist",
      "Years": "2015",
      "Subsequently": "",
      "Lab Website": ""
    },
    {
      "Name": "Jared Toettcher",
      "Position": "Postdoc",
      "Years": "2010-2015",
      "Subsequently": "Assistant Professor of Molecular Biology, Princeton University",
      "Lab Website": "http://molbio.princeton.edu/faculty/molbio-faculty/795-toettcher"
    },
    {
      "Name": "Elias Puchner",
      "Position": "Postdoc",
      "Years": "2010-2014",
      "Subsequently": "Assistant Professor of Physics, University of Minnesota",
      "Lab Website": "http://www.physics.umn.edu/people/puchner.html"
    },
    {
      "Name": "Lei Stanley Qi",
      "Position": "Systems Biology Fellow",
      "Years": "2012-2014",
      "Subsequently": "Assistant Professor of Bioengineering, Stanford University",
      "Lab Website": "https://med.stanford.edu/qilab.html"
    },
    {
      "Name": "Lingfeng (Kitty) Liu",
      "Position": "Postdoc",
      "Years": "2010-2014",
      "Subsequently": "",
      "Lab Website": ""
    },
    {
      "Name": "Hyun Youk",
      "Position": "Postdoc",
      "Years": "2011-2014",
      "Subsequently": "Assistant Professor of Physics & Nanobiology, Delft University of Technology, the Netherlands",
      "Lab Website": "http://www.youklab.org"
    },
    {
      "Name": "Jesse Zalatan",
      "Position": "Postdoc",
      "Years": "2008-2014",
      "Subsequently": "Assistant Professor of Chemistry, University of Washington, Seattle",
      "Lab Website": "http://depts.washington.edu/chem/people/faculty/zalatan.html"
    },
    {
      "Name": "Thomas Stevens",
      "Position": "Graduate Student",
      "Years": "2012-2014",
      "Subsequently": "Masters degree in Biophysics, UCSF",
      "Lab Website": ""
    },
    {
      "Name": "Jaline Gerardin",
      "Position": "Graduate Student",
      "Years": "2007-2014",
      "Subsequently": "Research Scientist, Institute for Disease Modeling, Intellectual Ventures Labs",
      "Lab Website": ""
    },
    {
      "Name": "Veronica Zepeda",
      "Position": "Science Education",
      "Years": "2011-2013",
      "Subsequently": "Lecturer, Department of Biochemistry and Molecular Biology, University of Nevada, Reno",
      "Lab Website": ""
    },
    {
      "Name": "Jessica Walter",
      "Position": "Postdoc",
      "Years": "2009-2013",
      "Subsequently": "Scientist, Amyris",
      "Lab Website": ""
    },
    {
      "Name": "Reid Williams",
      "Position": "Graduate Student",
      "Years": "2006-2013",
      "Subsequently": "Bioscience resident, IDEO",
      "Lab Website": ""
    },
    {
      "Name": "Maria Borovinskaya",
      "Position": "Postdoc",
      "Years": "2009-2013",
      "Subsequently": "",
      "Lab Website": ""
    },
    {
      "Name": "Jason Park",
      "Position": "Graduate Student",
      "Years": "2008-2013",
      "Subsequently": "UCSF MSTP",
      "Lab Website": ""
    },
    {
      "Name": "Ping (Andy) Wei",
      "Position": "Postdoc",
      "Years": "2007-2013",
      "Subsequently": "Assistant Professor, Center for Quantitative Biology, Peking University, China",
      "Lab Website": "http://cqb.pku.edu.cn/WeiLab/"
    },
    {
      "Name": "Simon Lee",
      "Position": "Research Associate",
      "Years": "",
      "Subsequently": "",
      "Lab Website": ""
    },
    {
      "Name": "Mia Morgan",
      "Position": "Administrative Manager",
      "Years": "2011-2012",
      "Subsequently": "Financial Analyst, Department of Cellular and Molecular Pharmacology, University of California, San Francisco",
      "Lab Website": ""
    },
    {
      "Name": "Pedro Beltrao",
      "Position": "Postdoc",
      "Years": "2008-2013",
      "Subsequently": "",
      "Lab Website": ""
    },
    {
      "Name": "Illes Farkas",
      "Position": "Postdoc",
      "Years": "visitor: 2012",
      "Subsequently": "Senior Research Associate, Statistical and Biological Physics group, Hungarian Academy of Sciences",
      "Lab Website": "http://hal.elte.hu/fij"
    },
    {
      "Name": "Angi Chau",
      "Position": "Graduate Student",
      "Years": "2004-2012",
      "Subsequently": "Director of Bourn Idea Lab, Castilleja School",
      "Lab Website": ""
    },
    {
      "Name": "Oliver Hoeller",
      "Position": "Postdoc",
      "Years": "2008-2012",
      "Subsequently": "Postdoctoral Fellow, Weiner Lab, University of California, San Francisco",
      "Lab Website": ""
    },
    {
      "Name": "Wilson Wong",
      "Position": "Postdoc",
      "Years": "2007-2012",
      "Subsequently": "Assistant professor, Biomedical Engineering, Boston University",
      "Lab Website": "http://www.bu.edu/wilsonwonglab/"
    },
    {
      "Name": "Jacinto Chen",
      "Position": "Junior Specialist",
      "Years": "",
      "Subsequently": "Undergraduate, University of California, Berkeley",
      "Lab Website": ""
    },
    {
      "Name": "Benjamin Rhau",
      "Position": "Graduate Student",
      "Years": "",
      "Subsequently": "",
      "Lab Website": ""
    },
    {
      "Name": "Silinda Neou",
      "Position": "Associate Specialist",
      "Years": "",
      "Subsequently": "",
      "Lab Website": ""
    },
    {
      "Name": "Raquel Gomes",
      "Position": "Science Education",
      "Years": "",
      "Subsequently": "Adjunct Professor, University of San Francisco",
      "Lab Website": ""
    },
    {
      "Name": "Andrew Horwitz",
      "Position": "Postdoc",
      "Years": "",
      "Subsequently": "Scientist, LS9",
      "Lab Website": ""
    },
    {
      "Name": "Leon Chan",
      "Position": "Postdoc",
      "Years": "",
      "Subsequently": "Postdoctoral Fellow, Weis Lab, University of California, Berkeley",
      "Lab Website": ""
    },
    {
      "Name": "Caleb Bashor",
      "Position": "Graduate Student",
      "Years": "",
      "Subsequently": "Postdoctoral Fellow, James J. Collins Lab, Boston University",
      "Lab Website": "http://bashorlab.rice.edu/"
    },
    {
      "Name": "Anselm Levskaya",
      "Position": "Postdoc",
      "Years": "",
      "Subsequently": "Postdoctoral Fellow, Deisseroth Lab, Stanford University",
      "Lab Website": ""
    },
    {
      "Name": "Matthew Good",
      "Position": "Graduate Student",
      "Years": "",
      "Subsequently": "Postdoctoral Fellow, Heald Lab, University of California, Berkeley",
      "Lab Website": "http://www.buenoscience.org/"
    },
    {
      "Name": "Angela Won",
      "Position": "Graduate Student",
      "Years": "",
      "Subsequently": "",
      "Lab Website": ""
    },
    {
      "Name": "Stacy Fang",
      "Position": "Junior Specialist (CPL)",
      "Years": "",
      "Subsequently": "Medical Student, New York Medical College",
      "Lab Website": ""
    },
    {
      "Name": "Liam Holt",
      "Position": "Postdoc",
      "Years": "",
      "Subsequently": "Bowes Research Fellow, University of California, Berkeley",
      "Lab Website": "https://www.liamholtlab.org/"
    },
    {
      "Name": "Albert Lu",
      "Position": "Research Associate",
      "Years": "",
      "Subsequently": "",
      "Lab Website": ""
    },
    {
      "Name": "Aynur Tasdemir",
      "Position": "Postdoc",
      "Years": "",
      "Subsequently": "Postdoctoral Fellow, Regeneron Pharmaceuticals",
      "Lab Website": ""
    },
    {
      "Name": "Sergio Peisajovich",
      "Position": "Postdoc",
      "Years": "",
      "Subsequently": "Staff Scientist, Illumina, Inc.",
      "Lab Website": ""
    },
    {
      "Name": "Noah Helman",
      "Position": "Postdoc",
      "Years": "",
      "Subsequently": "Scientist, LS9",
      "Lab Website": ""
    },
    {
      "Name": "Alice Willis",
      "Position": "Administrative Assistant",
      "Years": "",
      "Subsequently": "Administrative Assistant, Weissman Lab, University of California San Francisco",
      "Lab Website": ""
    },
    {
      "Name": "Alex Watters",
      "Position": "Postdoc",
      "Years": "",
      "Subsequently": "Scientist, Amgen",
      "Lab Website": "",
      "Contact": "awatters74 (at) yahoo.com"
    },
    {
      "Name": "Nili Sommovilla",
      "Position": "Science Education",
      "Years": "",
      "Subsequently": "Medical Student, University of California San Francisco",
      "Lab Website": "",
      "Contact": "nili.sommovilla (at) ucsf.edu"
    },
    {
      "Name": "Grace Tang",
      "Position": "Undergraduate Student",
      "Years": "",
      "Subsequently": "Student, Bioengineering Graduate Program, Stanford University",
      "Lab Website": "",
      "Contact": "gwtang (at) stanford.edu"
    },
    {
      "Name": "Farid Ahmad",
      "Position": "Postdoc",
      "Years": "",
      "Subsequently": "",
      "Lab Website": ""
    },
    {
      "Name": "Nathan Sallee",
      "Position": "Graduate Student",
      "Years": "",
      "Subsequently": "Scientist I, Protein Chemistry, Five Prime Therapeutics",
      "Lab Website": "",
      "Contact": "nsallee (at) gmail.com"
    },
    {
      "Name": "Shude Yan",
      "Position": "Postdoc",
      "Years": "",
      "Subsequently": "Researcher, Antibody Engineering, University of California San Francisco",
      "Lab Website": ""
    },
    {
      "Name": "Julie Singleton",
      "Position": "Research Associate",
      "Years": "",
      "Subsequently": "",
      "Lab Website": ""
    },
    {
      "Name": "Attila Remenyi",
      "Position": "Postdoc",
      "Years": "",
      "Subsequently": "Associate Research Professor, Eotvos Lorand University, Budapest, Hungary",
      "Lab Website": "",
      "Contact": "remenyi (at) elte.hu"
    },
    {
      "Name": "Brian Yeh",
      "Position": "Graduate Student",
      "Years": "",
      "Subsequently": "Postdoctoral Fellow, Weiss Lab, Northwestern University",
      "Lab Website": "",
      "Contact": "brian.yeh (at) northwestern.edu"
    },
    {
      "Name": "Amy Coombs",
      "Position": "Research Associate",
      "Years": "",
      "Subsequently": "",
      "Lab Website": ""
    },
    {
      "Name": "Keiko Petrosky",
      "Position": "Graduate Student",
      "Years": "",
      "Subsequently": "",
      "Lab Website": "",
      "Contact": "keikopet (at) gmail.com"
    },
    {
      "Name": "Brian Hillier",
      "Position": "Postdoc",
      "Years": "",
      "Subsequently": "Catalyst Biosciences",
      "Lab Website": "",
      "Contact": "brianhillier (at) gmail.com"
    },
    {
      "Name": "Anrica Deb",
      "Position": "Research Associate",
      "Years": "",
      "Subsequently": "Student, Graduate School of Journalism, University of California",
      "Lab Website": ""
    },
    {
      "Name": "Venizelos Papayannopoulos",
      "Position": "Graduate Student",
      "Years": "",
      "Subsequently": "Program Leader Track, Division of Molecular Immunology, MRC National Institute of Medical Research, London",
      "Lab Website": "",
      "Contact": "vpapaya (at) nimr.mrc.ac.uk"
    },
    {
      "Name": "Roby Bhattacharyya",
      "Position": "Graduate Student",
      "Years": "",
      "Subsequently": "Resident, Department of Medicine, Massachusetts General Hospital",
      "Lab Website": "",
      "Contact": "rbhattacharyya (at) partners.org"
    },
    {
      "Name": "Ethan Mirsky",
      "Position": "Research Associate",
      "Years": "",
      "Subsequently": "Biophysics Graduate Program, University of California San Francisco",
      "Lab Website": "",
      "Contact": "eamirsky (at) yahoo.com"
    },
    {
      "Name": "John Dueber",
      "Position": "Graduate Student",
      "Years": "",
      "Subsequently": "Assistant Professor, Department of Bioengineering, University of California, Berkeley",
      "Lab Website": "https://dueberlab.berkeley.edu/",
      "Contact": "jdueber (at) berkeley.edu"
    },
    {
      "Name": "Joseph McNulty",
      "Position": "Postdoc",
      "Years": "",
      "Subsequently": "Postdoctoral Fellow, Scot Wolf Lab, University of Massachusetts Worcester",
      "Lab Website": ""
    },
    {
      "Name": "Sang-Hyun Park",
      "Position": "Postdoc",
      "Years": "",
      "Subsequently": "Assistant Professor, School of Life Sciences, Seoul National University",
      "Lab Website": "",
      "Contact": "biopark (at) snu.ac.kr"
    },
    {
      "Name": "Kayam Chak",
      "Position": "Research Associate",
      "Years": "",
      "Subsequently": "Graduate Student, Johns Hopkins University",
      "Lab Website": "",
      "Contact": "kchak1 (at) jhmi.edu"
    },
    {
      "Name": "Ali Zarrinpar",
      "Position": "Graduate Student",
      "Years": "",
      "Subsequently": "Resident, Department of Surgery, University of California, Los Angeles",
      "Lab Website": "",
      "Contact": "azarrin (at) hotmail.com"
    },
    {
      "Name": "Baruch Z. Harris",
      "Position": "Graduate Student",
      "Years": "",
      "Subsequently": "Associate, McKinsey & Company",
      "Lab Website": "",
      "Contact": "baruchzh (at) hotmail.com"
    },
    {
      "Name": "Ken Prehoda",
      "Position": "Postdoc",
      "Years": "",
      "Subsequently": "Assistant Professor, Institute of Molecular Biology, University of Oregon",
      "Lab Website": "http://www.molbio.uoregon.edu/facres/prehoda.html",
      "Contact": "prehoda (at) molbio.uoregon.edu"
    },
    {
      "Name": "Jessica Scott",
      "Position": "Research Associate",
      "Years": "",
      "Subsequently": "Resident, Department of Pediatrics, University of Wisconsin",
      "Lab Website": "",
      "Contact": "jscott (at) uwhealth.org"
    },
    {
      "Name": "Do Lee",
      "Position": "Research Associate",
      "Years": "",
      "Subsequently": "Biosphere 2 Center, Oracle, AZ",
      "Lab Website": ""
    },
    {
      "Name": "Jack Nguyen",
      "Position": "Graduate Student",
      "Years": "",
      "Subsequently": "Catalyst Biosciences",
      "Lab Website": ""
    }
  ]

# %%
import pandas as pd

# %%
df = pd.DataFrame(initial_list)

# %%
df['start_year'] = df['Years'].str.split('-').str[0]
df['end_year'] = df['Years'].str.split('-').str[1]

# %%
df.to_csv('alumni.csv', index=False)

# %%
# !open .

# %%
# import csv
df = pd.read_csv('alumni.csv')

# iteratively build the jade markdown with entries in this format:
"""
li.alum
    h3.name John Dueber
    p Graduate Student
    p Subsequently: Assistant Professor, Department of Bioengineering, University of California, Berkeley
    p
        a(href="https://dueberlab.berkeley.edu/") Dueber Lab Website
"""
